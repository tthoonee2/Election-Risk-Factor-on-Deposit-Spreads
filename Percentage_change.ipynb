# %% [markdown]
# # Percentage change from day 1

# %% [markdown]
# ### Reload the data for simplicity

# %%
# Function to normalize dates relative to an election date
import pandas as pd
import os
from datetime import datetime, timedelta
import numpy as np

# Load the elections data
elections_df = pd.read_csv('DATA/Initial Data.csv')
# Main processing
all_dfs = []
csv_directory = 'DATA/INDICES/'
output_directory = 'DATA/OUTPUT/'

# Function to normalize dates relative to an election date
def normalize_dates(df, election_date):
    df['NormalizedDate'] = (df['Date'] - election_date).dt.days
    return df[(df['NormalizedDate'] >= -90) & (df['NormalizedDate'] <= 90)]

# Function to clean price data
def clean_price(price):
    if isinstance(price, str):
        return float(price.replace(',', ''))
    return float(price)

# Function to load and process index data
def process_index(file_path, election_date, index_name, election_name):
    df = pd.read_csv(file_path)
    df['Date'] = pd.to_datetime(df['Date'])
    df['Price'] = df['Price'].apply(clean_price)
    df = df.sort_values('Date')
   
    normalized_df = normalize_dates(df, election_date)
    if not normalized_df.empty:
        # Get the price at day -90 or the earliest available day
        start_date = normalized_df['NormalizedDate'].min()
        start_price = normalized_df.loc[normalized_df['NormalizedDate'] == start_date, 'Price'].iloc[0]
        normalized_df = normalized_df.copy()
        # Apply percentage change transformation
        normalized_df['Price'] = normalized_df['Price'].apply(lambda x: (x - start_price) / start_price * 100)
        
        column_name = f"{election_name}_{index_name}"
        return normalized_df[['NormalizedDate', 'Price']].rename(columns={'Price': column_name})
    return None

for _, election in elections_df.iterrows():
    index_name = election['Index']
    election_date = pd.to_datetime(election['Date 1'])
    election_name = f"{election['Year']}_{election['Elections']}"
    filep = csv_directory + index_name + ".csv"
    file_path = os.path.abspath(filep)
    print(file_path)
    if os.path.exists(file_path):
        processed_df = process_index(file_path, election_date, index_name, election_name)
        if processed_df is not None:
            all_dfs.append(processed_df)
    else:
        print(f"Warning: File not found for index {index_name}")

if all_dfs:
    merged_df = all_dfs[0]
    for df in all_dfs[1:]:
        merged_df = pd.merge(merged_df, df, on='NormalizedDate', how='outer')
    
    # Sort by NormalizedDate
    merged_df = merged_df.sort_values('NormalizedDate')
    
    # Fill NaN values using forward fill and then backward fill
    merged_df = merged_df.ffill().bfill()
    
    # Save the final dataframe to a CSV file
    merged_df.to_csv('log_norm_election_data.csv', index=False)
    print("Processing complete. Data saved to 'log_norm_election_data.csv'")
else:
    print("No data processed. Check your input files and paths.")
# Out:
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\FRFNN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\IBEXIB.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\NLFIN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\BNKI.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\FTATBNK.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\N3020PI.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\FTITLMS30.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\IBEXIB.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\IBEXIB.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\NYK.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\FRFNN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\FRFNN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\SX3010GI.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\FTITLMS30.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\CXPVX.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\TRGSPTS40.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\OFING.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\NLFIN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\NYK.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\NYK.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\NYK.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\IBEXIB.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\IBEXIB.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\PTFIN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\FTATBNK.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\BEFIN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\OMXC20.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\N3020PI.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\IBEXIB.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\SX3010GI.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\FTITLMS30.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\CXPVX.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\FRFNN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\FRFNN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\TRINMX302020.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\NLFIN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\NYK.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\NYK.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\NYK.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\IBEXIB.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\TRINMX302020.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\PTFIN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\IBEXIB.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\TRINMX302020.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\TRGSPTS40.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\SX3010GI.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\BEFIN.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\CXPVX.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\FTITLMS30.csv
# c:\Users\apuza\iCloudDrive\Intesa\Political Risk\UPDATE\DATA\INDICES\OFING.csv
# Processing complete. Data saved to 'log_norm_election_data.csv'

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Table, TableStyle
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib import colors

def create_pdf_report(results_df, recovery_times, avg_recovery_time, warnings, filename="summary.pdf"):
    doc = SimpleDocTemplate(filename, pagesize=letter)
    styles = getSampleStyleSheet()
    elements = []

    # Title
    elements.append(Paragraph("Election Analysis Summary", styles['Title']))
    elements.append(Spacer(1, 12))

    # Overall results
    elements.append(Paragraph("Overall Results", styles['Heading2']))
    overall_data = [
        ["Metric", "Value"],
        ["Linear Model", f"{linear_weighted_avg:.6f}"],
        ["Non-Linear 2nd Degree Model", f"{non_linear_2nd_weighted_avg:.6f}"],
        ["Non-Linear 3rd Degree Model", f"{non_linear_3rd_weighted_avg:.6f}"],
        ["Non-Linear 4th Degree Model", f"{non_linear_4th_weighted_avg:.6f}"],
        ["Overall Mean Effect", f"{overall_mean_effect:.6f}"],
    ]
    overall_table = Table(overall_data)
    overall_table.setStyle(TableStyle([
        ('BACKGROUND', (0, 0), (-1, 0), colors.grey),
        ('TEXTCOLOR', (0, 0), (-1, 0), colors.whitesmoke),
        ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
        ('FONTNAME', (0, 0), (-1, 0), 'Helvetica-Bold'),
        ('FONTSIZE', (0, 0), (-1, 0), 14),
        ('BOTTOMPADDING', (0, 0), (-1, 0), 12),
        ('BACKGROUND', (0, 1), (-1, -1), colors.beige),
        ('TEXTCOLOR', (0, 1), (-1, -1), colors.black),
        ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
        ('FONTNAME', (0, 1), (-1, -1), 'Helvetica'),
        ('FONTSIZE', (0, 1), (-1, -1), 12),
        ('TOPPADDING', (0, 1), (-1, -1), 6),
        ('BOTTOMPADDING', (0, 1), (-1, -1), 6),
        ('GRID', (0, 0), (-1, -1), 1, colors.black)
    ]))
    elements.append(overall_table)
    elements.append(Spacer(1, 12))

    # Negative impact elections (sorted by Mean Effect)
    elements.append(Paragraph("Elections with Negative Impact", styles['Heading2']))
    elements.append(Paragraph(f"Number of elections: {len(negative_elections)}", styles['Normal']))
    elements.append(Paragraph(f"Average coefficient: {avg_negative_coeff:.6f}", styles['Normal']))
    elements.append(Spacer(1, 12))

    sorted_negative = negative_elections.sort_values('Mean_Effect')
    neg_data = [["Election", "Mean Effect"]] + [[index, f"{row['Mean_Effect']:.6f}"] for index, row in sorted_negative.iterrows()]
    neg_table = Table(neg_data)
    neg_table.setStyle(TableStyle([
        ('BACKGROUND', (0, 0), (-1, 0), colors.grey),
        ('TEXTCOLOR', (0, 0), (-1, 0), colors.whitesmoke),
        ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
        ('FONTNAME', (0, 0), (-1, 0), 'Helvetica-Bold'),
        ('FONTSIZE', (0, 0), (-1, 0), 12),
        ('BOTTOMPADDING', (0, 0), (-1, 0), 12),
        ('BACKGROUND', (0, 1), (-1, -1), colors.beige),
        ('TEXTCOLOR', (0, 1), (-1, -1), colors.black),
        ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
        ('FONTNAME', (0, 1), (-1, -1), 'Helvetica'),
        ('FONTSIZE', (0, 1), (-1, -1), 10),
        ('TOPPADDING', (0, 1), (-1, -1), 6),
        ('BOTTOMPADDING', (0, 1), (-1, -1), 6),
        ('GRID', (0, 0), (-1, -1), 1, colors.black)
    ]))
    elements.append(neg_table)
    elements.append(Spacer(1, 12))

    # Positive impact elections (sorted by Mean Effect)
    elements.append(Paragraph("Elections with Positive Impact", styles['Heading2']))
    elements.append(Paragraph(f"Number of elections: {len(positive_elections)}", styles['Normal']))
    elements.append(Paragraph(f"Average coefficient: {avg_positive_coeff:.6f}", styles['Normal']))
    elements.append(Spacer(1, 12))

    sorted_positive = positive_elections.sort_values('Mean_Effect', ascending=False)
    pos_data = [["Election", "Mean Effect"]] + [[index, f"{row['Mean_Effect']:.6f}"] for index, row in sorted_positive.iterrows()]
    pos_table = Table(pos_data)
    pos_table.setStyle(TableStyle([
        ('BACKGROUND', (0, 0), (-1, 0), colors.grey),
        ('TEXTCOLOR', (0, 0), (-1, 0), colors.whitesmoke),
        ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
        ('FONTNAME', (0, 0), (-1, 0), 'Helvetica-Bold'),
        ('FONTSIZE', (0, 0), (-1, 0), 12),
        ('BOTTOMPADDING', (0, 0), (-1, 0), 12),
        ('BACKGROUND', (0, 1), (-1, -1), colors.beige),
        ('TEXTCOLOR', (0, 1), (-1, -1), colors.black),
        ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
        ('FONTNAME', (0, 1), (-1, -1), 'Helvetica'),
        ('FONTSIZE', (0, 1), (-1, -1), 10),
        ('TOPPADDING', (0, 1), (-1, -1), 6),
        ('BOTTOMPADDING', (0, 1), (-1, -1), 6),
        ('GRID', (0, 0), (-1, -1), 1, colors.black)
    ]))
    elements.append(pos_table)
    elements.append(Spacer(1, 12))

    # Recovery Time Analysis (sorted by recovery time)
    elements.append(Paragraph("Recovery Time Analysis", styles['Heading2']))
    elements.append(Paragraph(f"Average recovery time: {avg_recovery_time:.2f} days", styles['Normal']))
    elements.append(Spacer(1, 12))

    sorted_recovery_times = sorted(recovery_times, key=lambda x: x[1])
    recovery_data = [["Election", "Recovery Time (days)"]] + [[election, f"{time:.2f}"] for election, time in sorted_recovery_times]
    recovery_table = Table(recovery_data)
    recovery_table.setStyle(TableStyle([
        ('BACKGROUND', (0, 0), (-1, 0), colors.grey),
        ('TEXTCOLOR', (0, 0), (-1, 0), colors.whitesmoke),
        ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
        ('FONTNAME', (0, 0), (-1, 0), 'Helvetica-Bold'),
        ('FONTSIZE', (0, 0), (-1, 0), 12),
        ('BOTTOMPADDING', (0, 0), (-1, 0), 12),
        ('BACKGROUND', (0, 1), (-1, -1), colors.beige),
        ('TEXTCOLOR', (0, 1), (-1, -1), colors.black),
        ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
        ('FONTNAME', (0, 1), (-1, -1), 'Helvetica'),
        ('FONTSIZE', (0, 1), (-1, -1), 10),
        ('TOPPADDING', (0, 1), (-1, -1), 6),
        ('BOTTOMPADDING', (0, 1), (-1, -1), 6),
        ('GRID', (0, 0), (-1, -1), 1, colors.black)
    ]))
    elements.append(recovery_table)
    elements.append(Spacer(1, 12))

    # Warnings
    elements.append(Paragraph("Warnings", styles['Heading2']))
    for warning in warnings:
        elements.append(Paragraph(warning, styles['Normal']))

    # Build the PDF
    doc.build(elements)
    print(f"PDF report saved as {filename}")
    
    
def calculate_p_value(model, coefficient_name='intervention'):
    return model.pvalues[coefficient_name]

def extract_model_info(df, model_func):
    results = {}
    for election in df.columns[1:]:  # Exclude 'NormalizedDate'
        model = model_func(df[election], election)
        intervention_coeff = model.params['intervention']
        r_squared = model.rsquared
        p_value = calculate_p_value(model)
        results[election] = {'intervention_coeff': intervention_coeff, 'r_squared': r_squared, 'p_value': p_value}
    return results


def linear_its_analysis(series, election_name):
    df = pd.DataFrame({'date': merged_df['NormalizedDate'], 'index': series})
    df = df.sort_values('date').reset_index(drop=True)
    df['time'] = range(len(df))
    df['intervention'] = (df['date'] >= 0).astype(int)
    df['time_after_intervention'] = np.where(df['date'] >= 0, df['time'] - df[df['date'] >= 0]['time'].min(), 0)
    
    X = sm.add_constant(df[['time', 'intervention', 'time_after_intervention']])
    return sm.OLS(df['index'], X).fit()

def non_linear_its_analysis_2nd_degree(series, election_name):
    df = pd.DataFrame({'date': merged_df['NormalizedDate'], 'index': series})
    df = df.sort_values('date').reset_index(drop=True)
    df['time'] = range(len(df))
    df['intervention'] = (df['date'] >= 0).astype(int)
    df['time_after_intervention'] = np.where(df['date'] >= 0, df['time'] - df[df['date'] >= 0]['time'].min(), 0)
    
    df['time_squared'] = df['time'] ** 2
    df['time_after_intervention_squared'] = df['time_after_intervention'] ** 2
    
    X = sm.add_constant(df[['time', 'time_squared', 'intervention', 'time_after_intervention', 'time_after_intervention_squared']])
    return sm.OLS(df['index'], X).fit()

def non_linear_its_analysis_3rd_degree(series, election_name):
    df = pd.DataFrame({'date': merged_df['NormalizedDate'], 'index': series})
    df = df.sort_values('date').reset_index(drop=True)
    df['time'] = range(len(df))
    df['intervention'] = (df['date'] >= 0).astype(int)
    df['time_after_intervention'] = np.where(df['date'] >= 0, df['time'] - df[df['date'] >= 0]['time'].min(), 0)
    
    df['time_squared'] = df['time'] ** 2
    df['time_after_intervention_squared'] = df['time_after_intervention'] ** 2
    df['time_3'] = df['time'] ** 3
    df['time_after_intervention_3'] = df['time_after_intervention'] ** 3
    
    X = sm.add_constant(df[['time', 'time_squared', 'time_3', 'intervention', 'time_after_intervention', 'time_after_intervention_squared', 'time_after_intervention_3']])
    return sm.OLS(df['index'], X).fit()


def non_linear_its_analysis_4th_degree(series, election_name):
    df = pd.DataFrame({'date': merged_df['NormalizedDate'], 'index': series})
    df = df.sort_values('date').reset_index(drop=True)
    df['time'] = range(len(df))
    df['intervention'] = (df['date'] >= 0).astype(int)
    df['time_after_intervention'] = np.where(df['date'] >= 0, df['time'] - df[df['date'] >= 0]['time'].min(), 0)
    
    df['time_squared'] = df['time'] ** 2
    df['time_after_intervention_squared'] = df['time_after_intervention'] ** 2
    df['time_3'] = df['time'] ** 3
    df['time_after_intervention_3'] = df['time_after_intervention'] ** 3
    df['time_4'] = df['time'] ** 4
    df['time_after_intervention_4'] = df['time_after_intervention'] ** 4
    
    X = sm.add_constant(df[['time', 'time_squared', 'time_3', 'intervention', 'time_after_intervention', 'time_after_intervention_squared', 'time_after_intervention_3','time_4','time_after_intervention_4']])
    return sm.OLS(df['index'], X).fit()

def analyze_recovery_time(df):
    elections = df.columns[1:]  # Exclude 'NormalizedDate'
    recovery_times = []
    warnings = []
    for election in elections:
        # Check if there was a negative impact (percentage change became negative after election)
        post_election_changes = df[df['NormalizedDate'] >= 0][election]
        if post_election_changes.iloc[0] < 0:
            # Find the first day the percentage change returns to 0 or above
            recovery_day = post_election_changes[post_election_changes >= 0].index.min()
            
            if pd.notna(recovery_day):
                recovery_time = df.loc[recovery_day, 'NormalizedDate']
                recovery_times.append((election, recovery_time))
            else:
                warning = f"Warning: {election} did not recover within the analyzed period"
                warnings.append(warning)
                print(warning)
    return recovery_times, warnings

# Extract information for all three models
linear_results = extract_model_info(merged_df, linear_its_analysis)
non_linear_2nd_results = extract_model_info(merged_df, non_linear_its_analysis_2nd_degree)
non_linear_3rd_results = extract_model_info(merged_df, non_linear_its_analysis_3rd_degree)
non_linear_4th_results = extract_model_info(merged_df, non_linear_its_analysis_4th_degree)

# Create a DataFrame to store the results
results_df = pd.DataFrame({
    'Linear_Intervention': [linear_results[e]['intervention_coeff'] for e in linear_results],
    'Linear_R2': [linear_results[e]['r_squared'] for e in linear_results],
    'Linear_P': [linear_results[e]['p_value'] for e in linear_results],
    'NonLinear_2nd_Intervention': [non_linear_2nd_results[e]['intervention_coeff'] for e in non_linear_2nd_results],
    'NonLinear_2nd_R2': [non_linear_2nd_results[e]['r_squared'] for e in non_linear_2nd_results],
    'NonLinear_2nd_P': [non_linear_2nd_results[e]['p_value'] for e in non_linear_2nd_results],
    'NonLinear_3rd_Intervention': [non_linear_3rd_results[e]['intervention_coeff'] for e in non_linear_3rd_results],
    'NonLinear_3rd_R2': [non_linear_3rd_results[e]['r_squared'] for e in non_linear_3rd_results],
    'NonLinear_3rd_P': [non_linear_3rd_results[e]['p_value'] for e in non_linear_3rd_results],
    'NonLinear_4th_Intervention': [non_linear_4th_results[e]['intervention_coeff'] for e in non_linear_4th_results],
    'NonLinear_4th_R2': [non_linear_4th_results[e]['r_squared'] for e in non_linear_4th_results],
    'NonLinear_4th_P': [non_linear_4th_results[e]['p_value'] for e in non_linear_4th_results]
}, index=linear_results.keys())
# Calculate mean effect for each election

# Calculate weighted averages
def weighted_average(values, weights):
    return np.average(values, weights=weights)

def significant_mean(row, alpha=0.05):
    significant_values = [
        row['Linear_Intervention'] if row['Linear_P'] < alpha else np.nan,
        row['NonLinear_2nd_Intervention'] if row['NonLinear_2nd_P'] < alpha else np.nan,
        row['NonLinear_3rd_Intervention'] if row['NonLinear_3rd_P'] < alpha else np.nan,
        row['NonLinear_4th_Intervention'] if row['NonLinear_4th_P'] < alpha else np.nan
    ]
    return np.nanmean(significant_values)

results_df['Significant_Mean_Effect'] = results_df.apply(significant_mean, axis=1)

results_df['Mean_Effect'] = results_df[['Linear_Intervention', 'NonLinear_2nd_Intervention', 'NonLinear_3rd_Intervention','NonLinear_4th_Intervention']].mean(axis=1)

linear_weighted_avg = weighted_average(results_df['Linear_Intervention'], results_df['Linear_R2'])
non_linear_2nd_weighted_avg = weighted_average(results_df['NonLinear_2nd_Intervention'], results_df['NonLinear_2nd_R2'])
non_linear_3rd_weighted_avg = weighted_average(results_df['NonLinear_3rd_Intervention'], results_df['NonLinear_3rd_R2'])
non_linear_4th_weighted_avg = weighted_average(results_df['NonLinear_4th_Intervention'], results_df['NonLinear_4th_R2'])

# Calculate overall mean effect
overall_mean_effect = np.mean([linear_weighted_avg, non_linear_2nd_weighted_avg, non_linear_3rd_weighted_avg,non_linear_4th_weighted_avg])
negative_elections = results_df[results_df['Significant_Mean_Effect'] < 0]
positive_elections = results_df[results_df['Significant_Mean_Effect'] > 0]

avg_negative_coeff = negative_elections['Significant_Mean_Effect'].mean()
avg_positive_coeff = positive_elections['Significant_Mean_Effect'].mean()


print("Results DataFrame (sorted by Mean Effect):")
print(results_df.sort_values('Mean_Effect', ascending=False))

print("\nWeighted Averages:")
print(f"Linear Model: {linear_weighted_avg}")
print(f"Non-Linear 2nd Degree Model: {non_linear_2nd_weighted_avg}")
print(f"Non-Linear 3rd Degree Model: {non_linear_3rd_weighted_avg}")
print(f"Non-Linear 4th Degree Model: {non_linear_4th_weighted_avg}")
print(f"\nOverall Mean Effect: {overall_mean_effect}")

print(f"\nNumber of elections with significant negative impact: {len(negative_elections)}")
print(f"Average coefficient for elections with significant negative impact: {avg_negative_coeff:.6f}")
print("\nElections with significant negative impact (sorted by Significant Mean Effect):")
print(negative_elections[['Significant_Mean_Effect']].sort_values('Significant_Mean_Effect'))

print(f"\nNumber of elections with significant positive impact: {len(positive_elections)}")
print(f"Average coefficient for elections with significant positive impact: {avg_positive_coeff:.6f}")
print("\nElections with significant positive impact (sorted by Significant Mean Effect, descending):")
print(positive_elections[['Significant_Mean_Effect']].sort_values('Significant_Mean_Effect', ascending=False))

df = pd.read_csv('log_norm_election_data.csv')
# Perform recovery time analysis
recovery_times, warnings = analyze_recovery_time(df)
if recovery_times:
    avg_recovery_time = np.mean([time for _, time in recovery_times])
    print(f"\nAverage recovery time: {avg_recovery_time:.2f} days")
    print("\nRecovery times for each negatively impacted election (sorted by recovery time):")
    for election, time in sorted(recovery_times, key=lambda x: x[1]):
        print(f"{election}: {time:.2f} days")
else:
    avg_recovery_time = 0
    print("No elections with negative impact and subsequent recovery were found.")

# Create the PDF report with the new recovery time analysis and warnings
create_pdf_report(results_df, recovery_times, avg_recovery_time, warnings, 'log_summary.pdf')

# Create the PDF report with the new recovery time analysis

# Sort elections by mean effect
sorted_elections = results_df.sort_values('Mean_Effect', ascending=False)
print("\nAll Elections Sorted by Mean Effect (descending):")
print(sorted_elections[['Mean_Effect']])
# Out:
# Results DataFrame (sorted by Mean Effect):
#                                                     Linear_Intervention  \
# 2015_Portuguese legislative election_PTFIN                    14.349396
# 2023_Greek legislative election_FTATBNK                       17.312150
# 2023_Polish parliamentary election_BNKI                       18.587508
# 2017_French presidential election_FRFNN                        6.122316
# 2020_United States House of Representatives ele...             9.036387
# 2020_United States Senate elections_NYK                        9.036387
# 2020_United States presidential election_NYK                   9.036387
# 2016_United States presidential election_NYK                   6.898449
# 2016_United States House of Representatives ele...             6.898449
# 2016_United States Senate elections_NYK                        6.898449
# 2023_Finnish parliamentary election_N3020PI                    3.872543
# 2022_Swedish general election_SX3010GI                        -1.276142
# 2023_Italian local elections_FTITLMS30                         1.109710
# 2022_United States elections_NYK                               8.475943
# 2019_Portuguese legislative election_PTFIN                    10.558479
# 2014_Belgian federal election_BEFIN                            3.257989
# 2019_Danish general election_OMXC20                            1.304084
# 2014_Swedish general election_SX3010GI                         0.284324
# 2023_Dutch general election_NLFIN                              8.663533
# 2015_United Kingdom general election_TRINMX302020             -0.542003
# 2019_Finnish parliamentary election_N3020PI                   -0.160352
# 2017_French legislative election_FRFNN                        -0.510093
# 2023_Spanish regional elections_IBEXIB                         3.233077
# 2023_Spanish local elections_IBEXIB                            3.233077
# 2013_Norwegian parliamentary election_OFING                   -6.593445
# 2013_German federal election_CXPVX                             1.446437
# 2022_French presidential election_FRFNN                        6.027706
# 2019_Belgian federal election_BEFIN                           -2.232119
# 2023_Spanish general election_IBEXIB                           1.479564
# 2024_French Senate election_FRFNN                             -0.166600
# 2017_Dutch general election_NLFIN                              0.227893
# 2021_German federal election_CXPVX                            -1.548325
# 2015_Spanish general election_IBEXIB                         -10.943835
# 2018_Italian general election_FTITLMS30                       -1.866447
# 2017_German federal election_CXPVX                            -0.327500
# 2017_United Kingdom general election_TRINMX302020             -1.769787
# 2018_Swedish general election_SX3010GI                        -2.583026
# 2021_Dutch general election_NLFIN                              3.368895
# 2021_Norwegian parliamentary election_OFING                    1.284864
# 2019_Spanish general election_IBEXIB_x                        -4.090922
# 2019_Spanish general election_IBEXIB                          -4.090922
# 2019_Spanish general election_IBEXIB_y                        -3.493130
# 2016_United Kingdom Brexit_TRINMX302020                       -4.491153
# 2022_French legislative election_FRFNN                        -8.747880
# 2022_Italian general election_FTITLMS30                       -3.182641
# 2013_Italian general election_FTITLMS30                      -23.141460
# 2016_Spanish general election_IBEXIB                         -10.887196
# 2019_Greek legislative election_FTATBNK                      -12.154412
#
#                                                     Linear_R2      Linear_P  \
# 2015_Portuguese legislative election_PTFIN           0.862621  3.557518e-29
# 2023_Greek legislative election_FTATBNK              0.855123  4.120390e-24
# 2023_Polish parliamentary election_BNKI              0.941716  1.005177e-40
# 2017_French presidential election_FRFNN              0.905867  2.890921e-25
# 2020_United States House of Representatives ele...   0.907994  6.240143e-24
# 2020_United States Senate elections_NYK              0.907994  6.240143e-24
# 2020_United States presidential election_NYK         0.907994  6.240143e-24
# 2016_United States presidential election_NYK         0.947577  2.773066e-38
# 2016_United States House of Representatives ele...   0.947577  2.773066e-38
# 2016_United States Senate elections_NYK              0.947577  2.773066e-38
# 2023_Finnish parliamentary election_N3020PI          0.305312  1.895126e-05
# 2022_Swedish general election_SX3010GI               0.816874  1.192858e-01
# 2023_Italian local elections_FTITLMS30               0.053351  3.482501e-01
# 2022_United States elections_NYK                     0.619932  2.465668e-16
# 2019_Portuguese legislative election_PTFIN           0.750814  6.684821e-14
# 2014_Belgian federal election_BEFIN                  0.378908  2.317537e-10
# 2019_Danish general election_OMXC20                  0.280409  1.770189e-03
# 2014_Swedish general election_SX3010GI               0.555825  6.162437e-01
# 2023_Dutch general election_NLFIN                    0.811653  1.237687e-32
# 2015_United Kingdom general election_TRINMX302020    0.635113  3.269659e-01
# 2019_Finnish parliamentary election_N3020PI          0.644499  8.163296e-01
# 2017_French legislative election_FRFNN               0.764699  3.809785e-01
# 2023_Spanish regional elections_IBEXIB               0.594822  7.925808e-04
# 2023_Spanish local elections_IBEXIB                  0.594822  7.925808e-04
# 2013_Norwegian parliamentary election_OFING          0.812065  6.084474e-14
# 2013_German federal election_CXPVX                   0.791782  1.646355e-03
# 2022_French presidential election_FRFNN              0.814063  9.411975e-08
# 2019_Belgian federal election_BEFIN                  0.251504  7.970934e-03
# 2023_Spanish general election_IBEXIB                 0.826023  2.140752e-02
# 2024_French Senate election_FRFNN                    0.022738  3.741822e-01
# 2017_Dutch general election_NLFIN                    0.690299  6.389058e-01
# 2021_German federal election_CXPVX                   0.730591  8.727010e-03
# 2015_Spanish general election_IBEXIB                 0.841085  2.195679e-14
# 2018_Italian general election_FTITLMS30              0.220049  1.190219e-01
# 2017_German federal election_CXPVX                   0.926738  2.870296e-01
# 2017_United Kingdom general election_TRINMX302020    0.901737  1.763980e-05
# 2018_Swedish general election_SX3010GI               0.830284  1.138737e-04
# 2021_Dutch general election_NLFIN                    0.936718  2.438761e-05
# 2021_Norwegian parliamentary election_OFING          0.825934  1.177746e-01
# 2019_Spanish general election_IBEXIB_x               0.686410  1.541836e-08
# 2019_Spanish general election_IBEXIB                 0.686410  1.541836e-08
# 2019_Spanish general election_IBEXIB_y               0.674804  4.722474e-04
# 2016_United Kingdom Brexit_TRINMX302020              0.693425  4.752186e-08
# 2022_French legislative election_FRFNN               0.756590  1.097102e-20
# 2022_Italian general election_FTITLMS30              0.828139  4.183089e-03
# 2013_Italian general election_FTITLMS30              0.548639  5.960208e-32
# 2016_Spanish general election_IBEXIB                 0.594180  1.398306e-13
# 2019_Greek legislative election_FTATBNK              0.548073  1.889453e-06
#
#                                                     NonLinear_2nd_Intervention  \
# 2015_Portuguese legislative election_PTFIN                           17.065891
# 2023_Greek legislative election_FTATBNK                               3.445244
# 2023_Polish parliamentary election_BNKI                               7.717385
# 2017_French presidential election_FRFNN                               6.040053
# 2020_United States House of Representatives ele...                    4.887884
# 2020_United States Senate elections_NYK                               4.887884
# 2020_United States presidential election_NYK                          4.887884
# 2016_United States presidential election_NYK                          4.977141
# 2016_United States House of Representatives ele...                    4.977141
# 2016_United States Senate elections_NYK                               4.977141
# 2023_Finnish parliamentary election_N3020PI                           6.943419
# 2022_Swedish general election_SX3010GI                               -0.744357
# 2023_Italian local elections_FTITLMS30                               12.105922
# 2022_United States elections_NYK                                      5.729047
# 2019_Portuguese legislative election_PTFIN                           -2.071926
# 2014_Belgian federal election_BEFIN                                   3.254938
# 2019_Danish general election_OMXC20                                   4.568692
# 2014_Swedish general election_SX3010GI                                1.728005
# 2023_Dutch general election_NLFIN                                     3.868011
# 2015_United Kingdom general election_TRINMX302020                     2.509756
# 2019_Finnish parliamentary election_N3020PI                           2.779271
# 2017_French legislative election_FRFNN                               -2.059642
# 2023_Spanish regional elections_IBEXIB                               -1.921512
# 2023_Spanish local elections_IBEXIB                                  -1.921512
# 2013_Norwegian parliamentary election_OFING                          -2.268706
# 2013_German federal election_CXPVX                                    1.841422
# 2022_French presidential election_FRFNN                               1.093357
# 2019_Belgian federal election_BEFIN                                  -3.349475
# 2023_Spanish general election_IBEXIB                                  0.166540
# 2024_French Senate election_FRFNN                                     0.340047
# 2017_Dutch general election_NLFIN                                    -1.144220
# 2021_German federal election_CXPVX                                   -0.024305
# 2015_Spanish general election_IBEXIB                                  3.554836
# 2018_Italian general election_FTITLMS30                              -7.348515
# 2017_German federal election_CXPVX                                   -0.185313
# 2017_United Kingdom general election_TRINMX302020                    -3.633806
# 2018_Swedish general election_SX3010GI                                0.694113
# 2021_Dutch general election_NLFIN                                    -2.383703
# 2021_Norwegian parliamentary election_OFING                          -6.413087
# 2019_Spanish general election_IBEXIB_x                               -2.805795
# 2019_Spanish general election_IBEXIB                                 -2.805795
# 2019_Spanish general election_IBEXIB_y                               -6.623243
# 2016_United Kingdom Brexit_TRINMX302020                              -7.974320
# 2022_French legislative election_FRFNN                               -7.765872
# 2022_Italian general election_FTITLMS30                             -10.997495
# 2013_Italian general election_FTITLMS30                              -5.984645
# 2016_Spanish general election_IBEXIB                                 -4.858432
# 2019_Greek legislative election_FTATBNK                             -12.743930
#
#                                                     NonLinear_2nd_R2  \
# 2015_Portuguese legislative election_PTFIN                  0.883247
# 2023_Greek legislative election_FTATBNK                     0.930626
# 2023_Polish parliamentary election_BNKI                     0.971423
# 2017_French presidential election_FRFNN                     0.907891
# 2020_United States House of Representatives ele...          0.936630
# 2020_United States Senate elections_NYK                     0.936630
# 2020_United States presidential election_NYK                0.936630
# 2016_United States presidential election_NYK                0.965698
# 2016_United States House of Representatives ele...          0.965698
# 2016_United States Senate elections_NYK                     0.965698
# 2023_Finnish parliamentary election_N3020PI                 0.725779
# 2022_Swedish general election_SX3010GI                      0.817914
# 2023_Italian local elections_FTITLMS30                      0.429230
# 2022_United States elections_NYK                            0.824196
# 2019_Portuguese legislative election_PTFIN                  0.895172
# 2014_Belgian federal election_BEFIN                         0.380718
# 2019_Danish general election_OMXC20                         0.505325
# 2014_Swedish general election_SX3010GI                      0.609001
# 2023_Dutch general election_NLFIN                           0.868303
# 2015_United Kingdom general election_TRINMX302020           0.689269
# 2019_Finnish parliamentary election_N3020PI                 0.859282
# 2017_French legislative election_FRFNN                      0.806111
# 2023_Spanish regional elections_IBEXIB                      0.649644
# 2023_Spanish local elections_IBEXIB                         0.649644
# 2013_Norwegian parliamentary election_OFING                 0.840730
# 2013_German federal election_CXPVX                          0.856693
# 2022_French presidential election_FRFNN                     0.831970
# 2019_Belgian federal election_BEFIN                         0.590787
# 2023_Spanish general election_IBEXIB                        0.888565
# 2024_French Senate election_FRFNN                           0.083091
# 2017_Dutch general election_NLFIN                           0.701589
# 2021_German federal election_CXPVX                          0.868907
# 2015_Spanish general election_IBEXIB                        0.962279
# 2018_Italian general election_FTITLMS30                     0.522056
# 2017_German federal election_CXPVX                          0.939941
# 2017_United Kingdom general election_TRINMX302020           0.911397
# 2018_Swedish general election_SX3010GI                      0.867780
# 2021_Dutch general election_NLFIN                           0.965641
# 2021_Norwegian parliamentary election_OFING                 0.932689
# 2019_Spanish general election_IBEXIB_x                      0.758731
# 2019_Spanish general election_IBEXIB                        0.758731
# 2019_Spanish general election_IBEXIB_y                      0.725554
# 2016_United Kingdom Brexit_TRINMX302020                     0.761635
# 2022_French legislative election_FRFNN                      0.769029
# 2022_Italian general election_FTITLMS30                     0.883014
# 2013_Italian general election_FTITLMS30                     0.789750
# 2016_Spanish general election_IBEXIB                        0.703269
# 2019_Greek legislative election_FTATBNK                     0.672601
#
#                                                     NonLinear_2nd_P  \
# 2015_Portuguese legislative election_PTFIN             2.117408e-23
# 2023_Greek legislative election_FTATBNK                2.569342e-02
# 2023_Polish parliamentary election_BNKI                8.593007e-11
# 2017_French presidential election_FRFNN                1.105004e-13
# 2020_United States House of Representatives ele...     9.956019e-07
# 2020_United States Senate elections_NYK                9.956019e-07
# 2020_United States presidential election_NYK           9.956019e-07
# 2016_United States presidential election_NYK           1.400018e-18
# 2016_United States House of Representatives ele...     1.400018e-18
# 2016_United States Senate elections_NYK                1.400018e-18
# 2023_Finnish parliamentary election_N3020PI            2.549533e-14
# 2022_Swedish general election_SX3010GI                 5.449380e-01
# 2023_Italian local elections_FTITLMS30                 1.718126e-15
# 2022_United States elections_NYK                       1.348307e-08
# 2019_Portuguese legislative election_PTFIN             1.044992e-01
# 2014_Belgian federal election_BEFIN                    1.473938e-05
# 2019_Danish general election_OMXC20                    7.554892e-16
# 2014_Swedish general election_SX3010GI                 3.258047e-02
# 2023_Dutch general election_NLFIN                      5.098768e-07
# 2015_United Kingdom general election_TRINMX302020      1.306870e-03
# 2019_Finnish parliamentary election_N3020PI            3.541768e-05
# 2017_French legislative election_FRFNN                 1.046769e-02
# 2023_Spanish regional elections_IBEXIB                 1.500850e-01
# 2023_Spanish local elections_IBEXIB                    1.500850e-01
# 2013_Norwegian parliamentary election_OFING            4.491759e-02
# 2013_German federal election_CXPVX                     1.386273e-03
# 2022_French presidential election_FRFNN                4.824882e-01
# 2019_Belgian federal election_BEFIN                    4.026393e-04
# 2023_Spanish general election_IBEXIB                   8.290302e-01
# 2024_French Senate election_FRFNN                      2.153163e-01
# 2017_Dutch general election_NLFIN                      1.130537e-01
# 2021_German federal election_CXPVX                     9.685102e-01
# 2015_Spanish general election_IBEXIB                   3.130564e-04
# 2018_Italian general election_FTITLMS30                5.052034e-07
# 2017_German federal election_CXPVX                     6.589765e-01
# 2017_United Kingdom general election_TRINMX302020      2.084118e-09
# 2018_Swedish general election_SX3010GI                 4.270716e-01
# 2021_Dutch general election_NLFIN                      6.441935e-03
# 2021_Norwegian parliamentary election_OFING            1.924386e-14
# 2019_Spanish general election_IBEXIB_x                 2.464410e-03
# 2019_Spanish general election_IBEXIB                   2.464410e-03
# 2019_Spanish general election_IBEXIB_y                 2.477829e-06
# 2016_United Kingdom Brexit_TRINMX302020                1.601953e-12
# 2022_French legislative election_FRFNN                 1.312766e-09
# 2022_Italian general election_FTITLMS30                1.217464e-13
# 2013_Italian general election_FTITLMS30                3.547780e-04
# 2016_Spanish general election_IBEXIB                   6.168944e-03
# 2019_Greek legislative election_FTATBNK                8.560744e-05
#
#                                                     NonLinear_3rd_Intervention  \
# 2015_Portuguese legislative election_PTFIN                           13.079910
# 2023_Greek legislative election_FTATBNK                              12.097514
# 2023_Polish parliamentary election_BNKI                               4.129276
# 2017_French presidential election_FRFNN                               8.974802
# 2020_United States House of Representatives ele...                    3.971211
# 2020_United States Senate elections_NYK                               3.971211
# 2020_United States presidential election_NYK                          3.971211
# 2016_United States presidential election_NYK                          2.770044
# 2016_United States House of Representatives ele...                    2.770044
# 2016_United States Senate elections_NYK                               2.770044
# 2023_Finnish parliamentary election_N3020PI                           4.662689
# 2022_Swedish general election_SX3010GI                                9.396274
# 2023_Italian local elections_FTITLMS30                                4.332592
# 2022_United States elections_NYK                                      0.827568
# 2019_Portuguese legislative election_PTFIN                           -1.894311
# 2014_Belgian federal election_BEFIN                                   2.489653
# 2019_Danish general election_OMXC20                                   1.290987
# 2014_Swedish general election_SX3010GI                                2.838203
# 2023_Dutch general election_NLFIN                                    -2.598086
# 2015_United Kingdom general election_TRINMX302020                     0.792276
# 2019_Finnish parliamentary election_N3020PI                           2.021222
# 2017_French legislative election_FRFNN                                2.421232
# 2023_Spanish regional elections_IBEXIB                                3.409210
# 2023_Spanish local elections_IBEXIB                                   3.409210
# 2013_Norwegian parliamentary election_OFING                           7.091088
# 2013_German federal election_CXPVX                                    0.121653
# 2022_French presidential election_FRFNN                              -4.108989
# 2019_Belgian federal election_BEFIN                                   3.172162
# 2023_Spanish general election_IBEXIB                                  1.447838
# 2024_French Senate election_FRFNN                                    -0.534818
# 2017_Dutch general election_NLFIN                                    -0.343328
# 2021_German federal election_CXPVX                                    0.493050
# 2015_Spanish general election_IBEXIB                                  2.877533
# 2018_Italian general election_FTITLMS30                               5.290889
# 2017_German federal election_CXPVX                                   -0.897609
# 2017_United Kingdom general election_TRINMX302020                     1.163591
# 2018_Swedish general election_SX3010GI                                1.467306
# 2021_Dutch general election_NLFIN                                    -4.034549
# 2021_Norwegian parliamentary election_OFING                          -2.553574
# 2019_Spanish general election_IBEXIB_x                               -0.702488
# 2019_Spanish general election_IBEXIB                                 -0.702488
# 2019_Spanish general election_IBEXIB_y                               -5.487821
# 2016_United Kingdom Brexit_TRINMX302020                              -5.816741
# 2022_French legislative election_FRFNN                               -3.489092
# 2022_Italian general election_FTITLMS30                              -5.207844
# 2013_Italian general election_FTITLMS30                               5.729867
# 2016_Spanish general election_IBEXIB                                 -5.166491
# 2019_Greek legislative election_FTATBNK                              -1.857749
#
#                                                     NonLinear_3rd_R2  \
# 2015_Portuguese legislative election_PTFIN                  0.899857
# 2023_Greek legislative election_FTATBNK                     0.947279
# 2023_Polish parliamentary election_BNKI                     0.983962
# 2017_French presidential election_FRFNN                     0.941090
# 2020_United States House of Representatives ele...          0.937249
# 2020_United States Senate elections_NYK                     0.937249
# 2020_United States presidential election_NYK                0.937249
# 2016_United States presidential election_NYK                0.970733
# 2016_United States House of Representatives ele...          0.970733
# 2016_United States Senate elections_NYK                     0.970733
# 2023_Finnish parliamentary election_N3020PI                 0.743587
# 2022_Swedish general election_SX3010GI                      0.910020
# 2023_Italian local elections_FTITLMS30                      0.643606
# 2022_United States elections_NYK                            0.862984
# 2019_Portuguese legislative election_PTFIN                  0.918438
# 2014_Belgian federal election_BEFIN                         0.516046
# 2019_Danish general election_OMXC20                         0.674288
# 2014_Swedish general election_SX3010GI                      0.627924
# 2023_Dutch general election_NLFIN                           0.942173
# 2015_United Kingdom general election_TRINMX302020           0.730776
# 2019_Finnish parliamentary election_N3020PI                 0.860881
# 2017_French legislative election_FRFNN                      0.858430
# 2023_Spanish regional elections_IBEXIB                      0.694677
# 2023_Spanish local elections_IBEXIB                         0.694677
# 2013_Norwegian parliamentary election_OFING                 0.933872
# 2013_German federal election_CXPVX                          0.867941
# 2022_French presidential election_FRFNN                     0.872244
# 2019_Belgian federal election_BEFIN                         0.750482
# 2023_Spanish general election_IBEXIB                        0.893206
# 2024_French Senate election_FRFNN                           0.203340
# 2017_Dutch general election_NLFIN                           0.810548
# 2021_German federal election_CXPVX                          0.876477
# 2015_Spanish general election_IBEXIB                        0.971872
# 2018_Italian general election_FTITLMS30                     0.826483
# 2017_German federal election_CXPVX                          0.941811
# 2017_United Kingdom general election_TRINMX302020           0.957458
# 2018_Swedish general election_SX3010GI                      0.891198
# 2021_Dutch general election_NLFIN                           0.967210
# 2021_Norwegian parliamentary election_OFING                 0.947877
# 2019_Spanish general election_IBEXIB_x                      0.782101
# 2019_Spanish general election_IBEXIB                        0.782101
# 2019_Spanish general election_IBEXIB_y                      0.726950
# 2016_United Kingdom Brexit_TRINMX302020                     0.773746
# 2022_French legislative election_FRFNN                      0.835013
# 2022_Italian general election_FTITLMS30                     0.906449
# 2013_Italian general election_FTITLMS30                     0.870496
# 2016_Spanish general election_IBEXIB                        0.703582
# 2019_Greek legislative election_FTATBNK                     0.701796
#
#                                                     NonLinear_3rd_P  \
# 2015_Portuguese legislative election_PTFIN             2.529362e-11
# 2023_Greek legislative election_FTATBNK                2.195606e-10
# 2023_Polish parliamentary election_BNKI                3.178923e-04
# 2017_French presidential election_FRFNN                4.069286e-22
# 2020_United States House of Representatives ele...     2.389405e-03
# 2020_United States Senate elections_NYK                2.389405e-03
# 2020_United States presidential election_NYK           2.389405e-03
# 2016_United States presidential election_NYK           1.652017e-05
# 2016_United States House of Representatives ele...     1.652017e-05
# 2016_United States Senate elections_NYK                1.652017e-05
# 2023_Finnish parliamentary election_N3020PI            2.896849e-05
# 2022_Swedish general election_SX3010GI                 9.097007e-14
# 2023_Italian local elections_FTITLMS30                 3.610977e-03
# 2022_United States elections_NYK                       4.688189e-01
# 2019_Portuguese legislative election_PTFIN             2.097262e-01
# 2014_Belgian federal election_BEFIN                    4.602284e-03
# 2019_Danish general election_OMXC20                    2.246211e-02
# 2014_Swedish general election_SX3010GI                 7.624915e-03
# 2023_Dutch general election_NLFIN                      1.197910e-04
# 2015_United Kingdom general election_TRINMX302020      4.106423e-01
# 2019_Finnish parliamentary election_N3020PI            2.201318e-02
# 2017_French legislative election_FRFNN                 8.795699e-03
# 2023_Spanish regional elections_IBEXIB                 4.237253e-02
# 2023_Spanish local elections_IBEXIB                    4.237253e-02
# 2013_Norwegian parliamentary election_OFING            1.043256e-11
# 2013_German federal election_CXPVX                     8.679928e-01
# 2022_French presidential election_FRFNN                2.520659e-02
# 2019_Belgian federal election_BEFIN                    1.355078e-03
# 2023_Spanish general election_IBEXIB                   1.546562e-01
# 2024_French Senate election_FRFNN                      1.201587e-01
# 2017_Dutch general election_NLFIN                      6.558650e-01
# 2021_German federal election_CXPVX                     5.393982e-01
# 2015_Spanish general election_IBEXIB                   1.113723e-02
# 2018_Italian general election_FTITLMS30                6.798515e-06
# 2017_German federal election_CXPVX                     1.072178e-01
# 2017_United Kingdom general election_TRINMX302020      3.103086e-02
# 2018_Swedish general election_SX3010GI                 1.691208e-01
# 2021_Dutch general election_NLFIN                      4.856063e-04
# 2021_Norwegian parliamentary election_OFING            5.448398e-03
# 2019_Spanish general election_IBEXIB_x                 5.476606e-01
# 2019_Spanish general election_IBEXIB                   5.476606e-01
# 2019_Spanish general election_IBEXIB_y                 2.989674e-03
# 2016_United Kingdom Brexit_TRINMX302020                3.597489e-05
# 2022_French legislative election_FRFNN                 1.210126e-02
# 2022_Italian general election_FTITLMS30                1.785258e-03
# 2013_Italian general election_FTITLMS30                1.143164e-03
# 2016_Spanish general election_IBEXIB                   2.945993e-02
# 2019_Greek legislative election_FTATBNK                6.480299e-01
#
#                                                     NonLinear_4th_Intervention  \
# 2015_Portuguese legislative election_PTFIN                           14.049174
# 2023_Greek legislative election_FTATBNK                               9.670984
# 2023_Polish parliamentary election_BNKI                               2.721331
# 2017_French presidential election_FRFNN                               6.838952
# 2020_United States House of Representatives ele...                    3.353814
# 2020_United States Senate elections_NYK                               3.353814
# 2020_United States presidential election_NYK                          3.353814
# 2016_United States presidential election_NYK                          4.405111
# 2016_United States House of Representatives ele...                    4.405111
# 2016_United States Senate elections_NYK                               4.405111
# 2023_Finnish parliamentary election_N3020PI                           1.456547
# 2022_Swedish general election_SX3010GI                                7.461602
# 2023_Italian local elections_FTITLMS30                               -2.751538
# 2022_United States elections_NYK                                     -2.315399
# 2019_Portuguese legislative election_PTFIN                            5.527760
# 2014_Belgian federal election_BEFIN                                   2.441970
# 2019_Danish general election_OMXC20                                   0.676858
# 2014_Swedish general election_SX3010GI                                1.735360
# 2023_Dutch general election_NLFIN                                    -3.775737
# 2015_United Kingdom general election_TRINMX302020                     0.843886
# 2019_Finnish parliamentary election_N3020PI                          -1.126684
# 2017_French legislative election_FRFNN                                2.697250
# 2023_Spanish regional elections_IBEXIB                               -2.199708
# 2023_Spanish local elections_IBEXIB                                  -2.199708
# 2013_Norwegian parliamentary election_OFING                           4.268776
# 2013_German federal election_CXPVX                                   -0.921967
# 2022_French presidential election_FRFNN                              -0.889898
# 2019_Belgian federal election_BEFIN                                   3.146620
# 2023_Spanish general election_IBEXIB                                 -2.755235
# 2024_French Senate election_FRFNN                                     0.659833
# 2017_Dutch general election_NLFIN                                     1.077443
# 2021_German federal election_CXPVX                                    0.463784
# 2015_Spanish general election_IBEXIB                                  1.998223
# 2018_Italian general election_FTITLMS30                               0.871693
# 2017_German federal election_CXPVX                                   -1.879932
# 2017_United Kingdom general election_TRINMX302020                     0.843992
# 2018_Swedish general election_SX3010GI                               -3.339751
# 2021_Dutch general election_NLFIN                                    -0.915248
# 2021_Norwegian parliamentary election_OFING                           1.508489
# 2019_Spanish general election_IBEXIB_x                               -3.303170
# 2019_Spanish general election_IBEXIB                                 -3.303170
# 2019_Spanish general election_IBEXIB_y                               -0.637759
# 2016_United Kingdom Brexit_TRINMX302020                              -1.382078
# 2022_French legislative election_FRFNN                               -0.988413
# 2022_Italian general election_FTITLMS30                              -5.023715
# 2013_Italian general election_FTITLMS30                              -2.335248
# 2016_Spanish general election_IBEXIB                                 -8.593039
# 2019_Greek legislative election_FTATBNK                              -6.378420
#
#                                                     NonLinear_4th_R2  \
# 2015_Portuguese legislative election_PTFIN                  0.906832
# 2023_Greek legislative election_FTATBNK                     0.954455
# 2023_Polish parliamentary election_BNKI                     0.985156
# 2017_French presidential election_FRFNN                     0.952078
# 2020_United States House of Representatives ele...          0.965778
# 2020_United States Senate elections_NYK                     0.965778
# 2020_United States presidential election_NYK                0.965778
# 2016_United States presidential election_NYK                0.972767
# 2016_United States House of Representatives ele...          0.972767
# 2016_United States Senate elections_NYK                     0.972767
# 2023_Finnish parliamentary election_N3020PI                 0.772332
# 2022_Swedish general election_SX3010GI                      0.923681
# 2023_Italian local elections_FTITLMS30                      0.747431
# 2022_United States elections_NYK                            0.891603
# 2019_Portuguese legislative election_PTFIN                  0.945885
# 2014_Belgian federal election_BEFIN                         0.516126
# 2019_Danish general election_OMXC20                         0.694512
# 2014_Swedish general election_SX3010GI                      0.645804
# 2023_Dutch general election_NLFIN                           0.944090
# 2015_United Kingdom general election_TRINMX302020           0.791172
# 2019_Finnish parliamentary election_N3020PI                 0.912380
# 2017_French legislative election_FRFNN                      0.859835
# 2023_Spanish regional elections_IBEXIB                      0.759273
# 2023_Spanish local elections_IBEXIB                         0.759273
# 2013_Norwegian parliamentary election_OFING                 0.944104
# 2013_German federal election_CXPVX                          0.883922
# 2022_French presidential election_FRFNN                     0.876318
# 2019_Belgian federal election_BEFIN                         0.818311
# 2023_Spanish general election_IBEXIB                        0.911925
# 2024_French Senate election_FRFNN                           0.362894
# 2017_Dutch general election_NLFIN                           0.850715
# 2021_German federal election_CXPVX                          0.904514
# 2015_Spanish general election_IBEXIB                        0.973278
# 2018_Italian general election_FTITLMS30                     0.853232
# 2017_German federal election_CXPVX                          0.946785
# 2017_United Kingdom general election_TRINMX302020           0.958277
# 2018_Swedish general election_SX3010GI                      0.928311
# 2021_Dutch general election_NLFIN                           0.975985
# 2021_Norwegian parliamentary election_OFING                 0.958425
# 2019_Spanish general election_IBEXIB_x                      0.793548
# 2019_Spanish general election_IBEXIB                        0.793548
# 2019_Spanish general election_IBEXIB_y                      0.818984
# 2016_United Kingdom Brexit_TRINMX302020                     0.798640
# 2022_French legislative election_FRFNN                      0.847180
# 2022_Italian general election_FTITLMS30                     0.943609
# 2013_Italian general election_FTITLMS30                     0.912254
# 2016_Spanish general election_IBEXIB                        0.722578
# 2019_Greek legislative election_FTATBNK                     0.784892
#
#                                                     NonLinear_4th_P  \
# 2015_Portuguese legislative election_PTFIN             2.483893e-09
# 2023_Greek legislative election_FTATBNK                8.299756e-06
# 2023_Polish parliamentary election_BNKI                4.771634e-02
# 2017_French presidential election_FRFNN                3.995664e-12
# 2020_United States House of Representatives ele...     5.817421e-03
# 2020_United States Senate elections_NYK                5.817421e-03
# 2020_United States presidential election_NYK           5.817421e-03
# 2016_United States presidential election_NYK           3.306967e-08
# 2016_United States House of Representatives ele...     3.306967e-08
# 2016_United States Senate elections_NYK                3.306967e-08
# 2023_Finnish parliamentary election_N3020PI            2.607455e-01
# 2022_Swedish general election_SX3010GI                 1.132507e-07
# 2023_Italian local elections_FTITLMS30                 7.957530e-02
# 2022_United States elections_NYK                       7.214512e-02
# 2019_Portuguese legislative election_PTFIN             4.576904e-04
# 2014_Belgian federal election_BEFIN                    2.695434e-02
# 2019_Danish general election_OMXC20                    3.246001e-01
# 2014_Swedish general election_SX3010GI                 1.818421e-01
# 2023_Dutch general election_NLFIN                      7.873535e-06
# 2015_United Kingdom general election_TRINMX302020      4.304418e-01
# 2019_Finnish parliamentary election_N3020PI            2.001448e-01
# 2017_French legislative election_FRFNN                 1.987980e-02
# 2023_Spanish regional elections_IBEXIB                 2.406825e-01
# 2023_Spanish local elections_IBEXIB                    2.406825e-01
# 2013_Norwegian parliamentary election_OFING            2.136242e-04
# 2013_German federal election_CXPVX                     2.878799e-01
# 2022_French presidential election_FRFNN                6.942485e-01
# 2019_Belgian federal election_BEFIN                    3.105415e-03
# 2023_Spanish general election_IBEXIB                   1.873364e-02
# 2024_French Senate election_FRFNN                      8.959794e-02
# 2017_Dutch general election_NLFIN                      2.128590e-01
# 2021_German federal election_CXPVX                     6.028507e-01
# 2015_Spanish general election_IBEXIB                   1.493213e-01
# 2018_Italian general election_FTITLMS30                5.108815e-01
# 2017_German federal election_CXPVX                     5.536225e-03
# 2017_United Kingdom general election_TRINMX302020      2.087262e-01
# 2018_Swedish general election_SX3010GI                 2.508378e-03
# 2021_Dutch general election_NLFIN                      4.561610e-01
# 2021_Norwegian parliamentary election_OFING            1.420210e-01
# 2019_Spanish general election_IBEXIB_x                 2.231906e-02
# 2019_Spanish general election_IBEXIB                   2.231906e-02
# 2019_Spanish general election_IBEXIB_y                 7.338527e-01
# 2016_United Kingdom Brexit_TRINMX302020                3.984091e-01
# 2022_French legislative election_FRFNN                 5.550248e-01
# 2022_Italian general election_FTITLMS30                2.098359e-03
# 2013_Italian general election_FTITLMS30                1.961367e-01
# 2016_Spanish general election_IBEXIB                   3.195377e-03
# 2019_Greek legislative election_FTATBNK                1.448349e-01
#
#                                                     Significant_Mean_Effect  \
# 2015_Portuguese legislative election_PTFIN                        14.636093
# 2023_Greek legislative election_FTATBNK                           10.631473
# 2023_Polish parliamentary election_BNKI                            8.288875
# 2017_French presidential election_FRFNN                            6.994031
# 2020_United States House of Representatives ele...                 5.312324
# 2020_United States Senate elections_NYK                            5.312324
# 2020_United States presidential election_NYK                       5.312324
# 2016_United States presidential election_NYK                       4.762686
# 2016_United States House of Representatives ele...                 4.762686
# 2016_United States Senate elections_NYK                            4.762686
# 2023_Finnish parliamentary election_N3020PI                        5.159550
# 2022_Swedish general election_SX3010GI                             8.428938
# 2023_Italian local elections_FTITLMS30                             8.219257
# 2022_United States elections_NYK                                   7.102495
# 2019_Portuguese legislative election_PTFIN                         8.043119
# 2014_Belgian federal election_BEFIN                                2.861137
# 2019_Danish general election_OMXC20                                2.387921
# 2014_Swedish general election_SX3010GI                             2.283104
# 2023_Dutch general election_NLFIN                                  1.539430
# 2015_United Kingdom general election_TRINMX302020                  2.509756
# 2019_Finnish parliamentary election_N3020PI                        2.400246
# 2017_French legislative election_FRFNN                             1.019613
# 2023_Spanish regional elections_IBEXIB                             3.321143
# 2023_Spanish local elections_IBEXIB                                3.321143
# 2013_Norwegian parliamentary election_OFING                        0.624428
# 2013_German federal election_CXPVX                                 1.643930
# 2022_French presidential election_FRFNN                            0.959359
# 2019_Belgian federal election_BEFIN                                0.184297
# 2023_Spanish general election_IBEXIB                              -0.637836
# 2024_French Senate election_FRFNN                                       NaN
# 2017_Dutch general election_NLFIN                                       NaN
# 2021_German federal election_CXPVX                                -1.548325
# 2015_Spanish general election_IBEXIB                              -1.503822
# 2018_Italian general election_FTITLMS30                           -1.028813
# 2017_German federal election_CXPVX                                -1.879932
# 2017_United Kingdom general election_TRINMX302020                 -1.413334
# 2018_Swedish general election_SX3010GI                            -2.961388
# 2021_Dutch general election_NLFIN                                 -1.016452
# 2021_Norwegian parliamentary election_OFING                       -4.483330
# 2019_Spanish general election_IBEXIB_x                            -3.399962
# 2019_Spanish general election_IBEXIB                              -3.399962
# 2019_Spanish general election_IBEXIB_y                            -5.201398
# 2016_United Kingdom Brexit_TRINMX302020                           -6.094071
# 2022_French legislative election_FRFNN                            -6.667615
# 2022_Italian general election_FTITLMS30                           -6.102924
# 2013_Italian general election_FTITLMS30                           -7.798746
# 2016_Spanish general election_IBEXIB                              -7.376290
# 2019_Greek legislative election_FTATBNK                          -12.449171
#
#                                                     Mean_Effect
# 2015_Portuguese legislative election_PTFIN            14.636093
# 2023_Greek legislative election_FTATBNK               10.631473
# 2023_Polish parliamentary election_BNKI                8.288875
# 2017_French presidential election_FRFNN                6.994031
# 2020_United States House of Representatives ele...     5.312324
# 2020_United States Senate elections_NYK                5.312324
# 2020_United States presidential election_NYK           5.312324
# 2016_United States presidential election_NYK           4.762686
# 2016_United States House of Representatives ele...     4.762686
# 2016_United States Senate elections_NYK                4.762686
# 2023_Finnish parliamentary election_N3020PI            4.233799
# 2022_Swedish general election_SX3010GI                 3.709344
# 2023_Italian local elections_FTITLMS30                 3.699171
# 2022_United States elections_NYK                       3.179290
# 2019_Portuguese legislative election_PTFIN             3.030000
# 2014_Belgian federal election_BEFIN                    2.861137
# 2019_Danish general election_OMXC20                    1.960155
# 2014_Swedish general election_SX3010GI                 1.646473
# 2023_Dutch general election_NLFIN                      1.539430
# 2015_United Kingdom general election_TRINMX302020      0.900979
# 2019_Finnish parliamentary election_N3020PI            0.878364
# 2017_French legislative election_FRFNN                 0.637187
# 2023_Spanish regional elections_IBEXIB                 0.630266
# 2023_Spanish local elections_IBEXIB                    0.630266
# 2013_Norwegian parliamentary election_OFING            0.624428
# 2013_German federal election_CXPVX                     0.621886
# 2022_French presidential election_FRFNN                0.530544
# 2019_Belgian federal election_BEFIN                    0.184297
# 2023_Spanish general election_IBEXIB                   0.084677
# 2024_French Senate election_FRFNN                      0.074615
# 2017_Dutch general election_NLFIN                     -0.045553
# 2021_German federal election_CXPVX                    -0.153949
# 2015_Spanish general election_IBEXIB                  -0.628311
# 2018_Italian general election_FTITLMS30               -0.763095
# 2017_German federal election_CXPVX                    -0.822588
# 2017_United Kingdom general election_TRINMX302020     -0.849002
# 2018_Swedish general election_SX3010GI                -0.940339
# 2021_Dutch general election_NLFIN                     -0.991151
# 2021_Norwegian parliamentary election_OFING           -1.543327
# 2019_Spanish general election_IBEXIB_x                -2.725594
# 2019_Spanish general election_IBEXIB                  -2.725594
# 2019_Spanish general election_IBEXIB_y                -4.060488
# 2016_United Kingdom Brexit_TRINMX302020               -4.916073
# 2022_French legislative election_FRFNN                -5.247814
# 2022_Italian general election_FTITLMS30               -6.102924
# 2013_Italian general election_FTITLMS30               -6.432872
# 2016_Spanish general election_IBEXIB                  -7.376290
# 2019_Greek legislative election_FTATBNK               -8.283628
#
# Weighted Averages:
# Linear Model: 1.9296664959941594
# Non-Linear 2nd Degree Model: 0.4951171354383187
# Non-Linear 3rd Degree Model: 1.7885935030343787
# Non-Linear 4th Degree Model: 0.9244354097114207
#
# Overall Mean Effect: 1.2844531360445695
#
# Number of elections with significant negative impact: 18
# Average coefficient for elections with significant negative impact: -4.164632
#
# Elections with significant negative impact (sorted by Significant Mean Effect):
#                                                    Significant_Mean_Effect
# 2019_Greek legislative election_FTATBNK                         -12.449171
# 2013_Italian general election_FTITLMS30                          -7.798746
# 2016_Spanish general election_IBEXIB                             -7.376290
# 2022_French legislative election_FRFNN                           -6.667615
# 2022_Italian general election_FTITLMS30                          -6.102924
# 2016_United Kingdom Brexit_TRINMX302020                          -6.094071
# 2019_Spanish general election_IBEXIB_y                           -5.201398
# 2021_Norwegian parliamentary election_OFING                      -4.483330
# 2019_Spanish general election_IBEXIB_x                           -3.399962
# 2019_Spanish general election_IBEXIB                             -3.399962
# 2018_Swedish general election_SX3010GI                           -2.961388
# 2017_German federal election_CXPVX                               -1.879932
# 2021_German federal election_CXPVX                               -1.548325
# 2015_Spanish general election_IBEXIB                             -1.503822
# 2017_United Kingdom general election_TRINMX302020                -1.413334
# 2018_Italian general election_FTITLMS30                          -1.028813
# 2021_Dutch general election_NLFIN                                -1.016452
# 2023_Spanish general election_IBEXIB                             -0.637836
#
# Number of elections with significant positive impact: 28
# Average coefficient for elections with significant positive impact: 4.742299
#
# Elections with significant positive impact (sorted by Significant Mean Effect, descending):
#                                                     Significant_Mean_Effect
# 2015_Portuguese legislative election_PTFIN                        14.636093
# 2023_Greek legislative election_FTATBNK                           10.631473
# 2022_Swedish general election_SX3010GI                             8.428938
# 2023_Polish parliamentary election_BNKI                            8.288875
# 2023_Italian local elections_FTITLMS30                             8.219257
# 2019_Portuguese legislative election_PTFIN                         8.043119
# 2022_United States elections_NYK                                   7.102495
# 2017_French presidential election_FRFNN                            6.994031
# 2020_United States presidential election_NYK                       5.312324
# 2020_United States Senate elections_NYK                            5.312324
# 2020_United States House of Representatives ele...                 5.312324
# 2023_Finnish parliamentary election_N3020PI                        5.159550
# 2016_United States House of Representatives ele...                 4.762686
# 2016_United States Senate elections_NYK                            4.762686
# 2016_United States presidential election_NYK                       4.762686
# 2023_Spanish regional elections_IBEXIB                             3.321143
# 2023_Spanish local elections_IBEXIB                                3.321143
# 2014_Belgian federal election_BEFIN                                2.861137
# 2015_United Kingdom general election_TRINMX302020                  2.509756
# 2019_Finnish parliamentary election_N3020PI                        2.400246
# 2019_Danish general election_OMXC20                                2.387921
# 2014_Swedish general election_SX3010GI                             2.283104
# 2013_German federal election_CXPVX                                 1.643930
# 2023_Dutch general election_NLFIN                                  1.539430
# 2017_French legislative election_FRFNN                             1.019613
# 2022_French presidential election_FRFNN                            0.959359
# 2013_Norwegian parliamentary election_OFING                        0.624428
# 2019_Belgian federal election_BEFIN                                0.184297
# Warning: 2022_French presidential election_FRFNN did not recover within the analyzed period
# Warning: 2022_French legislative election_FRFNN did not recover within the analyzed period
# Warning: 2021_German federal election_CXPVX did not recover within the analyzed period
# Warning: 2019_Portuguese legislative election_PTFIN did not recover within the analyzed period
# Warning: 2016_Spanish general election_IBEXIB did not recover within the analyzed period
# Warning: 2015_Portuguese legislative election_PTFIN did not recover within the analyzed period
# Warning: 2015_Spanish general election_IBEXIB did not recover within the analyzed period
#
# Average recovery time: 17.14 days
#
# Recovery times for each negatively impacted election (sorted by recovery time):
# 2023_Polish parliamentary election_BNKI: 1.00 days
# 2023_Greek legislative election_FTATBNK: 1.00 days
# 2022_Swedish general election_SX3010GI: 1.00 days
# 2019_Spanish general election_IBEXIB_x: 1.00 days
# 2019_Spanish general election_IBEXIB: 1.00 days
# 2023_Dutch general election_NLFIN: 2.00 days
# 2019_Belgian federal election_BEFIN: 2.00 days
# 2019_Danish general election_OMXC20: 6.00 days
# 2014_Swedish general election_SX3010GI: 8.00 days
# 2014_Belgian federal election_BEFIN: 8.00 days
# 2022_Italian general election_FTITLMS30: 25.00 days
# 2023_Spanish local elections_IBEXIB: 60.00 days
# 2023_Spanish regional elections_IBEXIB: 60.00 days
# 2022_United States elections_NYK: 64.00 days
# PDF report saved as log_summary.pdf
#
# All Elections Sorted by Mean Effect (descending):
#                                                     Mean_Effect
# 2015_Portuguese legislative election_PTFIN            14.636093
# 2023_Greek legislative election_FTATBNK               10.631473
# 2023_Polish parliamentary election_BNKI                8.288875
# 2017_French presidential election_FRFNN                6.994031
# 2020_United States House of Representatives ele...     5.312324
# 2020_United States Senate elections_NYK                5.312324
# 2020_United States presidential election_NYK           5.312324
# 2016_United States presidential election_NYK           4.762686
# 2016_United States House of Representatives ele...     4.762686
# 2016_United States Senate elections_NYK                4.762686
# 2023_Finnish parliamentary election_N3020PI            4.233799
# 2022_Swedish general election_SX3010GI                 3.709344
# 2023_Italian local elections_FTITLMS30                 3.699171
# 2022_United States elections_NYK                       3.179290
# 2019_Portuguese legislative election_PTFIN             3.030000
# 2014_Belgian federal election_BEFIN                    2.861137
# 2019_Danish general election_OMXC20                    1.960155
# 2014_Swedish general election_SX3010GI                 1.646473
# 2023_Dutch general election_NLFIN                      1.539430
# 2015_United Kingdom general election_TRINMX302020      0.900979
# 2019_Finnish parliamentary election_N3020PI            0.878364
# 2017_French legislative election_FRFNN                 0.637187
# 2023_Spanish regional elections_IBEXIB                 0.630266
# 2023_Spanish local elections_IBEXIB                    0.630266
# 2013_Norwegian parliamentary election_OFING            0.624428
# 2013_German federal election_CXPVX                     0.621886
# 2022_French presidential election_FRFNN                0.530544
# 2019_Belgian federal election_BEFIN                    0.184297
# 2023_Spanish general election_IBEXIB                   0.084677
# 2024_French Senate election_FRFNN                      0.074615
# 2017_Dutch general election_NLFIN                     -0.045553
# 2021_German federal election_CXPVX                    -0.153949
# 2015_Spanish general election_IBEXIB                  -0.628311
# 2018_Italian general election_FTITLMS30               -0.763095
# 2017_German federal election_CXPVX                    -0.822588
# 2017_United Kingdom general election_TRINMX302020     -0.849002
# 2018_Swedish general election_SX3010GI                -0.940339
# 2021_Dutch general election_NLFIN                     -0.991151
# 2021_Norwegian parliamentary election_OFING           -1.543327
# 2019_Spanish general election_IBEXIB_x                -2.725594
# 2019_Spanish general election_IBEXIB                  -2.725594
# 2019_Spanish general election_IBEXIB_y                -4.060488
# 2016_United Kingdom Brexit_TRINMX302020               -4.916073
# 2022_French legislative election_FRFNN                -5.247814
# 2022_Italian general election_FTITLMS30               -6.102924
# 2013_Italian general election_FTITLMS30               -6.432872
# 2016_Spanish general election_IBEXIB                  -7.376290
# 2019_Greek legislative election_FTATBNK               -8.283628
# C:\Users\apuza\AppData\Local\Temp\ipykernel_7408\2921900159.py:265: RuntimeWarning: Mean of empty slice
#   return np.nanmean(significant_values)

# %%
def average(input):
    return np.average(input)

linear_weighted_avg_r2 = average(results_df['Linear_R2'])
non_linear_2nd_weighted_avg_r2 = average(results_df['NonLinear_2nd_R2'])
non_linear_3rd_weighted_avg_r2 = average(results_df['NonLinear_3rd_R2'])
non_linear_4th_weighted_avg_r2 = average(results_df['NonLinear_4th_R2'])
overall_mean_effect_r2 = np.mean([linear_weighted_avg_r2, non_linear_2nd_weighted_avg_r2, non_linear_3rd_weighted_avg_r2,non_linear_4th_weighted_avg_r2])
overall_mean_effect_r2
# Out:
# 0.7923600897135856

# %%
df = pd.read_csv('log_norm_election_data.csv')
df.head(10)
# Out:
#    NormalizedDate  2024_French Senate election_FRFNN  \
# 0             -90                           6.831878
# 1             -89                           6.825330
# 2             -88                           6.818968
# 3             -87                           6.818968
# 4             -86                           6.818968
# 5             -85                           6.844869
# 6             -84                           6.840183
# 7             -83                           6.859237
# 8             -82                           6.875779
# 9             -81                           6.874354
#
#    2023_Spanish general election_IBEXIB  2023_Dutch general election_NLFIN  \
# 0                              6.405063                           6.367106
# 1                              6.366642                           6.366488
# 2                              6.361648                           6.366488
# 3                              6.375876                           6.366488
# 4                              6.335763                           6.377356
# 5                              6.335763                           6.388528
# 6                              6.335763                           6.387199
# 7                              6.335763                           6.374087
# 8                              6.305180                           6.373695
# 9                              6.298214                           6.373695
#
#    2023_Polish parliamentary election_BNKI  \
# 0                                 9.054387
# 1                                 9.075743
# 2                                 9.074802
# 3                                 9.070154
# 4                                 9.062664
# 5                                 9.062664
# 6                                 9.062664
# 7                                 9.070309
# 8                                 9.068069
# 9                                 9.065039
#
#    2023_Greek legislative election_FTATBNK  \
# 0                                 6.814894
# 1                                 6.823863
# 2                                 6.781069
# 3                                 6.805590
# 4                                 6.804260
# 5                                 6.804260
# 6                                 6.804260
# 7                                 6.804260
# 8                                 6.835120
# 9                                 6.838480
#
#    2023_Finnish parliamentary election_N3020PI  \
# 0                                     8.011003
# 1                                     8.019955
# 2                                     8.031756
# 3                                     8.027695
# 4                                     8.027695
# 5                                     8.027695
# 6                                     8.027695
# 7                                     8.053238
# 8                                     8.046959
# 9                                     8.067572
#
#    2023_Italian local elections_FTITLMS30  \
# 0                                9.548411
# 1                                9.548411
# 2                                9.548411
# 3                                9.542984
# 4                                9.541585
# 5                                9.532011
# 6                                9.539694
# 7                                9.539694
# 8                                9.539694
# 9                                9.550371
#
#    2023_Spanish local elections_IBEXIB  \
# 0                             6.459748
# 1                             6.491179
# 2                             6.478202
# 3                             6.478510
# 4                             6.503090
# 5                             6.503090
# 6                             6.503090
# 7                             6.517080
# 8                             6.495870
# 9                             6.506382
#
#    2023_Spanish regional elections_IBEXIB  ...  \
# 0                                6.459748  ...
# 1                                6.491179  ...
# 2                                6.478202  ...
# 3                                6.478510  ...
# 4                                6.503090  ...
# 5                                6.503090  ...
# 6                                6.503090  ...
# 7                                6.517080  ...
# 8                                6.495870  ...
# 9                                6.506382  ...
#
#    2016_Spanish general election_IBEXIB  \
# 0                              6.422760
# 1                              6.422760
# 2                              6.423572
# 3                              6.400424
# 4                              6.386206
# 5                              6.386206
# 6                              6.386206
# 7                              6.380461
# 8                              6.343529
# 9                              6.338947
#
#    2016_United Kingdom Brexit_TRINMX302020  \
# 0                                 8.281539
# 1                                 8.281539
# 2                                 8.281539
# 3                                 8.281539
# 4                                 8.281539
# 5                                 8.296018
# 6                                 8.294962
# 7                                 8.288650
# 8                                 8.288650
# 9                                 8.288650
#
#    2015_Portuguese legislative election_PTFIN  \
# 0                                    4.598649
# 1                                    4.574711
# 2                                    4.595625
# 3                                    4.652435
# 4                                    4.702478
# 5                                    4.702478
# 6                                    4.702478
# 7                                    4.700299
# 8                                    4.687211
# 9                                    4.694828
#
#    2015_Spanish general election_IBEXIB  \
# 0                              6.671526
# 1                              6.671526
# 2                              6.671526
# 3                              6.671526
# 4                              6.671526
# 5                              6.671526
# 6                              6.671526
# 7                              6.671526
# 8                              6.671526
# 9                              6.671526
#
#    2015_United Kingdom general election_TRINMX302020  \
# 0                                           8.267359
# 1                                           8.267359
# 2                                           8.267359
# 3                                           8.257406
# 4                                           8.265887
# 5                                           8.262476
# 6                                           8.274036
# 7                                           8.278791
# 8                                           8.278791
# 9                                           8.278791
#
#    2014_Swedish general election_SX3010GI  \
# 0                                7.497623
# 1                                7.500413
# 2                                7.496442
# 3                                7.496192
# 4                                7.496192
# 5                                7.496192
# 6                                7.496192
# 7                                7.502242
# 8                                7.504105
# 9                                7.488165
#
#    2014_Belgian federal election_BEFIN  2013_German federal election_CXPVX  \
# 0                             6.384283                            6.633950
# 1                             6.389082                            6.649244
# 2                             6.383642                            6.668139
# 3                             6.382307                            6.673715
# 4                             6.391850                            6.680328
# 5                             6.391850                            6.680328
# 6                             6.391850                            6.680328
# 7                             6.353256                            6.682910
# 8                             6.382746                            6.687632
# 9                             6.383186                            6.672084
#
#    2013_Italian general election_FTITLMS30  \
# 0                                 9.216052
# 1                                 9.214293
# 2                                 9.206822
# 3                                 9.245151
# 4                                 9.240972
# 5                                 9.240972
# 6                                 9.240972
# 7                                 9.251789
# 8                                 9.271524
# 9                                 9.266921
#
#    2013_Norwegian parliamentary election_OFING
# 0                                     6.730397
# 1                                     6.712579
# 2                                     6.724433
# 3                                     6.725634
# 4                                     6.724613
# 5                                     6.724613
# 6                                     6.724613
# 7                                     6.739502
# 8                                     6.754627
# 9                                     6.745178
#
# [10 rows x 49 columns]

# %%
import pandas as pd
import numpy as np

# Load the normalized data
df = pd.read_csv('log_norm_election_data.csv')

def analyze_recovery_time(df):
    elections = df.columns[1:]  # Exclude 'NormalizedDate'
    recovery_times = []

    for election in elections:
        # Get pre-election price (at day 0 or the closest day before)
        pre_election_price = df[df['NormalizedDate'] <= 0][election].iloc[-1]
        
        # Check if there was a negative impact (price dropped after election)
        post_election_prices = df[df['NormalizedDate'] > 0][election]
        if post_election_prices.iloc[0] < pre_election_price:
            # Find the first day the price returns to or exceeds the pre-election price
            recovery_day = post_election_prices[post_election_prices > pre_election_price ].index.min()
            
            if pd.notna(recovery_day):
                recovery_time = df.loc[recovery_day, 'NormalizedDate']
                recovery_times.append((election, recovery_time))
            else:
                print(f"Warning: {election} did not recover within the analyzed period")

    return recovery_times

recovery_times = analyze_recovery_time(df)

if recovery_times:
    avg_recovery_time = np.mean([time for _, time in recovery_times])
    print(f"Average recovery time: {avg_recovery_time:.2f} days")
    
    print("\nRecovery times for each negatively impacted election:")
    for election, time in recovery_times:
        print(f"{election}: {time:.2f} days")
else:
    print("No elections with negative impact and subsequent recovery were found.")
# Out:
# Warning: 2023_Spanish general election_IBEXIB did not recover within the analyzed period
# Warning: 2023_Dutch general election_NLFIN did not recover within the analyzed period
# Warning: 2023_Finnish parliamentary election_N3020PI did not recover within the analyzed period
# Warning: 2023_Spanish local elections_IBEXIB did not recover within the analyzed period
# Warning: 2023_Spanish regional elections_IBEXIB did not recover within the analyzed period
# Warning: 2022_United States elections_NYK did not recover within the analyzed period
# Warning: 2022_French legislative election_FRFNN did not recover within the analyzed period
# Warning: 2021_Norwegian parliamentary election_OFING did not recover within the analyzed period
# Warning: 2020_United States presidential election_NYK did not recover within the analyzed period
# Warning: 2020_United States Senate elections_NYK did not recover within the analyzed period
# Warning: 2020_United States House of Representatives elections_NYK did not recover within the analyzed period
# Warning: 2019_Spanish general election_IBEXIB_y did not recover within the analyzed period
# Warning: 2019_Greek legislative election_FTATBNK did not recover within the analyzed period
# Warning: 2018_Italian general election_FTITLMS30 did not recover within the analyzed period
# Warning: 2017_French legislative election_FRFNN did not recover within the analyzed period
# Warning: 2016_Spanish general election_IBEXIB did not recover within the analyzed period
# Warning: 2016_United Kingdom Brexit_TRINMX302020 did not recover within the analyzed period
# Warning: 2015_Spanish general election_IBEXIB did not recover within the analyzed period
# Warning: 2014_Swedish general election_SX3010GI did not recover within the analyzed period
# Warning: 2013_German federal election_CXPVX did not recover within the analyzed period
# No elections with negative impact and subsequent recovery were found.

# %%
import pandas as pd
import numpy as np
from arch import arch_model
import warnings
warnings.filterwarnings('ignore')

# Load the data
data = pd.read_csv('log_norm_election_data.csv')
data.set_index('NormalizedDate', inplace=True)

def fit_figarch_and_get_volatility(series):
    # Remove NaN values
    series = series.dropna()
    
    # Reverse the series for FIGARCH modeling
    
    # Fit FIGARCH(1,d,1) model
    model = arch_model(series, vol='FIGARCH', p=1, o=0 ,q=0)
    
    try:
        results = model.fit(disp='off')
        # Extract conditional volatility
        volatility = np.sqrt(results.conditional_volatility)
        # Reverse the volatility series back to original order
        return pd.Series(volatility, index=series.index)
    except:
        print(f"Failed to fit EGARCH model for {series.name}")
        return pd.Series(index=series.index)

# Apply FIGARCH to each election time series and store results
volatilitydf = pd.DataFrame()
for column in data.columns:
    if column != 'NormalizedDate':
        volatility_column = f"{column}_volatility"
        volatilitydf[volatility_column] = fit_figarch_and_get_volatility(data[column])

# Save the results
volatilitydf.to_csv('election_data_with_figarch_volatility_corrected.csv')
print("Corrected FIGARCH volatility analysis complete. Results saved to 'election_data_with_figarch_volatility_corrected.csv'")
# Out:
# Corrected FIGARCH volatility analysis complete. Results saved to 'election_data_with_figarch_volatility_corrected.csv'

# %%
volatilitydf.count()
# Out:
# 2024_French Senate election_FRFNN_volatility                            181
# 2023_Spanish general election_IBEXIB_volatility                         181
# 2023_Dutch general election_NLFIN_volatility                            181
# 2023_Polish parliamentary election_BNKI_volatility                      181
# 2023_Greek legislative election_FTATBNK_volatility                      181
# 2023_Finnish parliamentary election_N3020PI_volatility                  181
# 2023_Italian local elections_FTITLMS30_volatility                       181
# 2023_Spanish local elections_IBEXIB_volatility                          181
# 2023_Spanish regional elections_IBEXIB_volatility                       181
# 2022_United States elections_NYK_volatility                             181
# 2022_French presidential election_FRFNN_volatility                      181
# 2022_French legislative election_FRFNN_volatility                       181
# 2022_Swedish general election_SX3010GI_volatility                       181
# 2022_Italian general election_FTITLMS30_volatility                      181
# 2021_German federal election_CXPVX_volatility                           181
# 2021_Norwegian parliamentary election_OFING_volatility                  181
# 2021_Dutch general election_NLFIN_volatility                            181
# 2020_United States presidential election_NYK_volatility                 181
# 2020_United States Senate elections_NYK_volatility                      181
# 2020_United States House of Representatives elections_NYK_volatility    181
# 2019_Spanish general election_IBEXIB_x_volatility                       181
# 2019_Spanish general election_IBEXIB_y_volatility                       181
# 2019_Portuguese legislative election_PTFIN_volatility                   181
# 2019_Greek legislative election_FTATBNK_volatility                      181
# 2019_Belgian federal election_BEFIN_volatility                          181
# 2019_Danish general election_OMXC20_volatility                          181
# 2019_Finnish parliamentary election_N3020PI_volatility                  181
# 2019_Spanish general election_IBEXIB_volatility                         181
# 2018_Swedish general election_SX3010GI_volatility                       181
# 2018_Italian general election_FTITLMS30_volatility                      181
# 2017_German federal election_CXPVX_volatility                           181
# 2017_French presidential election_FRFNN_volatility                      181
# 2017_French legislative election_FRFNN_volatility                       181
# 2017_United Kingdom general election_TRINMX302020_volatility            181
# 2017_Dutch general election_NLFIN_volatility                            181
# 2016_United States presidential election_NYK_volatility                 181
# 2016_United States Senate elections_NYK_volatility                      181
# 2016_United States House of Representatives elections_NYK_volatility    181
# 2016_Spanish general election_IBEXIB_volatility                         181
# 2016_United Kingdom Brexit_TRINMX302020_volatility                      181
# 2015_Portuguese legislative election_PTFIN_volatility                   181
# 2015_Spanish general election_IBEXIB_volatility                         181
# 2015_United Kingdom general election_TRINMX302020_volatility            181
# 2014_Swedish general election_SX3010GI_volatility                       181
# 2014_Belgian federal election_BEFIN_volatility                          181
# 2013_German federal election_CXPVX_volatility                           181
# 2013_Italian general election_FTITLMS30_volatility                      181
# 2013_Norwegian parliamentary election_OFING_volatility                  181
# dtype: int64

# %%
import pandas as pd
import numpy as np
from arch import arch_model
import warnings
warnings.filterwarnings('ignore')

# Load the data
volatilitydf = pd.read_csv('election_data_with_figarch_volatility_corrected.csv')
volatilitydf.set_index('NormalizedDate', inplace=True)

# Function to calculate average volatility for 10 days prior to election
def calculate_pre_election_volatility(df):
    volatility_data = {}
    
    for column in df.columns:
        if column.endswith('_volatility'):
            # Extract the election name (remove '_volatility' suffix)
            election_name = column[:-11]
            
            # Select data for 10 days prior to election (-10 to -1)
            pre_election_data = df.loc[-10:-1, column]
            
            # Calculate average volatility
            avg_volatility = pre_election_data.mean()
            
            volatility_data[election_name] = avg_volatility
    
    return pd.Series(volatility_data)

# Calculate pre-election volatility for each election
volatility_data = calculate_pre_election_volatility(volatilitydf)

# Display results
print("Average volatility for 10 days prior to each election:")
print(volatility_data)
volatility_data.to_csv("pre_election_volatility.csv")
# Out:
# Average volatility for 10 days prior to each election:
# 2024_French Senate election_FRFNN                            0.089542
# 2023_Spanish general election_IBEXIB                         0.138591
# 2023_Dutch general election_NLFIN                            0.165871
# 2023_Polish parliamentary election_BNKI                      0.250429
# 2023_Greek legislative election_FTATBNK                      0.402735
# 2023_Finnish parliamentary election_N3020PI                  0.213641
# 2023_Italian local elections_FTITLMS30                       0.171585
# 2023_Spanish local elections_IBEXIB                          0.202884
# 2023_Spanish regional elections_IBEXIB                       0.202884
# 2022_United States elections_NYK                             0.176038
# 2022_French presidential election_FRFNN                      0.196732
# 2022_French legislative election_FRFNN                       0.121106
# 2022_Swedish general election_SX3010GI                       0.154320
# 2022_Italian general election_FTITLMS30                      0.204862
# 2021_German federal election_CXPVX                           0.111566
# 2021_Norwegian parliamentary election_OFING                  0.097974
# 2021_Dutch general election_NLFIN                            0.211148
# 2020_United States presidential election_NYK                 0.178938
# 2020_United States Senate elections_NYK                      0.178938
# 2020_United States House of Representatives elections_NYK    0.178938
# 2019_Spanish general election_IBEXIB_x                       0.274463
# 2019_Spanish general election_IBEXIB_y                       0.151738
# 2019_Portuguese legislative election_PTFIN                   0.295672
# 2019_Greek legislative election_FTATBNK                      0.223701
# 2019_Belgian federal election_BEFIN                          0.111763
# 2019_Danish general election_OMXC20                          0.156381
# 2019_Finnish parliamentary election_N3020PI                  0.188140
# 2019_Spanish general election_IBEXIB                         0.274463
# 2018_Swedish general election_SX3010GI                       0.312811
# 2018_Italian general election_FTITLMS30                      0.102689
# 2017_German federal election_CXPVX                           0.095291
# 2017_French presidential election_FRFNN                      0.120568
# 2017_French legislative election_FRFNN                       0.149685
# 2017_United Kingdom general election_TRINMX302020            0.116716
# 2017_Dutch general election_NLFIN                            0.132815
# 2016_United States presidential election_NYK                 0.105971
# 2016_United States Senate elections_NYK                      0.105971
# 2016_United States House of Representatives elections_NYK    0.105971
# 2016_Spanish general election_IBEXIB                         0.211301
# 2016_United Kingdom Brexit_TRINMX302020                      0.225954
# 2015_Portuguese legislative election_PTFIN                   0.283874
# 2015_Spanish general election_IBEXIB                         0.275598
# 2015_United Kingdom general election_TRINMX302020            0.129573
# 2014_Swedish general election_SX3010GI                       0.147984
# 2014_Belgian federal election_BEFIN                          0.140270
# 2013_German federal election_CXPVX                           0.143083
# 2013_Italian general election_FTITLMS30                      0.270254
# 2013_Norwegian parliamentary election_OFING                  0.117487
# dtype: float64

# %%
binary_effect_data = pd.DataFrame(index=results_df.index)
binary_effect_data['Effect'] = (results_df['Mean_Effect'] < 0).astype(int)
print("\nBinary Classification of Election Effects:")
print(binary_effect_data)
binary_effect_data.to_csv('election_effect_classification.csv')

print("\nBinary classification dataset saved as 'election_effect_classification.csv'")
# Out:
# Binary Classification of Election Effects:
#                                                     Effect
# 2024_French Senate election_FRFNN                        0
# 2023_Spanish general election_IBEXIB                     0
# 2023_Dutch general election_NLFIN                        0
# 2023_Polish parliamentary election_BNKI                  0
# 2023_Greek legislative election_FTATBNK                  0
# 2023_Finnish parliamentary election_N3020PI              0
# 2023_Italian local elections_FTITLMS30                   0
# 2023_Spanish local elections_IBEXIB                      0
# 2023_Spanish regional elections_IBEXIB                   0
# 2022_United States elections_NYK                         0
# 2022_French presidential election_FRFNN                  0
# 2022_French legislative election_FRFNN                   1
# 2022_Swedish general election_SX3010GI                   0
# 2022_Italian general election_FTITLMS30                  1
# 2021_German federal election_CXPVX                       1
# 2021_Norwegian parliamentary election_OFING              1
# 2021_Dutch general election_NLFIN                        1
# 2020_United States presidential election_NYK             0
# 2020_United States Senate elections_NYK                  0
# 2020_United States House of Representatives ele...       0
# 2019_Spanish general election_IBEXIB_x                   1
# 2019_Spanish general election_IBEXIB_y                   1
# 2019_Portuguese legislative election_PTFIN               0
# 2019_Greek legislative election_FTATBNK                  1
# 2019_Belgian federal election_BEFIN                      0
# 2019_Danish general election_OMXC20                      0
# 2019_Finnish parliamentary election_N3020PI              0
# 2019_Spanish general election_IBEXIB                     1
# 2018_Swedish general election_SX3010GI                   1
# 2018_Italian general election_FTITLMS30                  1
# 2017_German federal election_CXPVX                       1
# 2017_French presidential election_FRFNN                  0
# 2017_French legislative election_FRFNN                   0
# 2017_United Kingdom general election_TRINMX302020        1
# 2017_Dutch general election_NLFIN                        1
# 2016_United States presidential election_NYK             0
# 2016_United States Senate elections_NYK                  0
# 2016_United States House of Representatives ele...       0
# 2016_Spanish general election_IBEXIB                     1
# 2016_United Kingdom Brexit_TRINMX302020                  1
# 2015_Portuguese legislative election_PTFIN               0
# 2015_Spanish general election_IBEXIB                     1
# 2015_United Kingdom general election_TRINMX302020        0
# 2014_Swedish general election_SX3010GI                   0
# 2014_Belgian federal election_BEFIN                      0
# 2013_German federal election_CXPVX                       0
# 2013_Italian general election_FTITLMS30                  1
# 2013_Norwegian parliamentary election_OFING              0
#
# Binary classification dataset saved as 'election_effect_classification.csv'

# %%
def analyze_election_prices(data):
    # Convert the 'NormalizedDate' column to integer
    data['NormalizedDate'] = data['NormalizedDate'].astype(int)

    # Initialize a dictionary to store results
    results = {}

    # Iterate through all columns except 'NormalizedDate'
    for column in data.columns[1:]:
        # Filter data for the range [-90, -1]
        pre_election_data = data[(data['NormalizedDate'] >= -90) & (data['NormalizedDate'] <= -1)][['NormalizedDate', column]]
        
        # Calculate the median for the range [-90, -1]
        median_90_to_1 = pre_election_data[column].median()
        
        # Calculate the average for the range [-10, -1]
        avg_10_to_1 = pre_election_data[
            (pre_election_data['NormalizedDate'] >= -10) & 
            (pre_election_data['NormalizedDate'] <= -1)
        ][column].mean()
        
        # Calculate the spread
        spread = avg_10_to_1 - median_90_to_1
        
        # Store the result
        results[column] = spread

    # Create a DataFrame from the results
    result_df = pd.DataFrame.from_dict(results, orient='index', columns=['Spread'])
    return result_df

# Load the data
result_df = pd.read_csv('log_norm_election_data.csv')

# Run the analysis
spread_data = analyze_election_prices(result_df)


spread_data.to_csv('election_price_spread_analysis.csv')



# Display the results
print(spread_data.count)
# Out:
# <bound method DataFrame.count of                                                       Spread
# 2024_French Senate election_FRFNN                   0.000000
# 2023_Spanish general election_IBEXIB                0.082518
# 2023_Dutch general election_NLFIN                   0.008645
# 2023_Polish parliamentary election_BNKI             0.011162
# 2023_Greek legislative election_FTATBNK             0.063145
# 2023_Finnish parliamentary election_N3020PI        -0.064800
# 2023_Italian local elections_FTITLMS30              0.000187
# 2023_Spanish local elections_IBEXIB                -0.031617
# 2023_Spanish regional elections_IBEXIB             -0.031617
# 2022_United States elections_NYK                   -0.006084
# 2022_French presidential election_FRFNN            -0.071794
# 2022_French legislative election_FRFNN             -0.022760
# 2022_Swedish general election_SX3010GI             -0.000697
# 2022_Italian general election_FTITLMS30             0.044366
# 2021_German federal election_CXPVX                 -0.034350
# 2021_Norwegian parliamentary election_OFING         0.009593
# 2021_Dutch general election_NLFIN                   0.144511
# 2020_United States presidential election_NYK       -0.024160
# 2020_United States Senate elections_NYK            -0.024160
# 2020_United States House of Representatives ele... -0.024160
# 2019_Spanish general election_IBEXIB_x              0.039211
# 2019_Spanish general election_IBEXIB_y              0.051791
# 2019_Portuguese legislative election_PTFIN         -0.085648
# 2019_Greek legislative election_FTATBNK             0.219426
# 2019_Belgian federal election_BEFIN                -0.012895
# 2019_Danish general election_OMXC20                -0.026694
# 2019_Finnish parliamentary election_N3020PI         0.060892
# 2019_Spanish general election_IBEXIB                0.039211
# 2018_Swedish general election_SX3010GI              0.044723
# 2018_Italian general election_FTITLMS30            -0.003185
# 2017_German federal election_CXPVX                  0.028304
# 2017_French presidential election_FRFNN             0.001648
# 2017_French legislative election_FRFNN              0.010354
# 2017_United Kingdom general election_TRINMX302020   0.057692
# 2017_Dutch general election_NLFIN                   0.021649
# 2016_United States presidential election_NYK       -0.004501
# 2016_United States Senate elections_NYK            -0.004501
# 2016_United States House of Representatives ele... -0.004501
# 2016_Spanish general election_IBEXIB               -0.081259
# 2016_United Kingdom Brexit_TRINMX302020            -0.038797
# 2015_Portuguese legislative election_PTFIN         -0.165311
# 2015_Spanish general election_IBEXIB               -0.076889
# 2015_United Kingdom general election_TRINMX302020   0.025122
# 2014_Swedish general election_SX3010GI             -0.011825
# 2014_Belgian federal election_BEFIN                -0.020128
# 2013_German federal election_CXPVX                  0.015700
# 2013_Italian general election_FTITLMS30             0.005543
# 2013_Norwegian parliamentary election_OFING        -0.003761>

# %%
# Load the data
spread_data = pd.read_csv('election_price_spread_analysis.csv', index_col=0)
volatility_data = pd.read_csv('pre_election_volatility.csv', index_col=0)
binary_effect_data = pd.read_csv('election_effect_classification.csv', index_col=0)

# %%
binary_effect_data
# Out:
#                                                     Effect
# 2024_French Senate election_FRFNN                        0
# 2023_Spanish general election_IBEXIB                     0
# 2023_Dutch general election_NLFIN                        0
# 2023_Polish parliamentary election_BNKI                  0
# 2023_Greek legislative election_FTATBNK                  0
# 2023_Finnish parliamentary election_N3020PI              0
# 2023_Italian local elections_FTITLMS30                   0
# 2023_Spanish local elections_IBEXIB                      0
# 2023_Spanish regional elections_IBEXIB                   0
# 2022_United States elections_NYK                         0
# 2022_French presidential election_FRFNN                  0
# 2022_French legislative election_FRFNN                   1
# 2022_Swedish general election_SX3010GI                   0
# 2022_Italian general election_FTITLMS30                  1
# 2021_German federal election_CXPVX                       1
# 2021_Norwegian parliamentary election_OFING              1
# 2021_Dutch general election_NLFIN                        1
# 2020_United States presidential election_NYK             0
# 2020_United States Senate elections_NYK                  0
# 2020_United States House of Representatives ele...       0
# 2019_Spanish general election_IBEXIB_x                   1
# 2019_Spanish general election_IBEXIB_y                   1
# 2019_Portuguese legislative election_PTFIN               0
# 2019_Greek legislative election_FTATBNK                  1
# 2019_Belgian federal election_BEFIN                      0
# 2019_Danish general election_OMXC20                      0
# 2019_Finnish parliamentary election_N3020PI              0
# 2019_Spanish general election_IBEXIB                     1
# 2018_Swedish general election_SX3010GI                   1
# 2018_Italian general election_FTITLMS30                  1
# 2017_German federal election_CXPVX                       1
# 2017_French presidential election_FRFNN                  0
# 2017_French legislative election_FRFNN                   0
# 2017_United Kingdom general election_TRINMX302020        1
# 2017_Dutch general election_NLFIN                        1
# 2016_United States presidential election_NYK             0
# 2016_United States Senate elections_NYK                  0
# 2016_United States House of Representatives ele...       0
# 2016_Spanish general election_IBEXIB                     1
# 2016_United Kingdom Brexit_TRINMX302020                  1
# 2015_Portuguese legislative election_PTFIN               0
# 2015_Spanish general election_IBEXIB                     1
# 2015_United Kingdom general election_TRINMX302020        0
# 2014_Swedish general election_SX3010GI                   0
# 2014_Belgian federal election_BEFIN                      0
# 2013_German federal election_CXPVX                       0
# 2013_Italian general election_FTITLMS30                  1
# 2013_Norwegian parliamentary election_OFING              0

# %% [markdown]
# ## Forecasting the effect of the direction of the election using Volatility and Price

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler

# Load the data
spread_data = pd.read_csv('election_price_spread_analysis.csv', index_col=0)
volatility_data = pd.read_csv('pre_election_volatility.csv', index_col=0)
binary_effect_data = pd.read_csv('election_effect_classification.csv', index_col=0)

# Reset index for volatility_data to match the other datasets
volatility_data = volatility_data.reset_index()
volatility_data.index = spread_data.index
volatility_data = volatility_data.drop(columns=['index'])

# Combine spread and volatility
X = pd.merge(spread_data, volatility_data, left_index=True, right_index=True, how='inner')

# Ensure all datasets have the same index
common_index = X.index.intersection(binary_effect_data.index)
X = X.loc[common_index]
y = binary_effect_data.loc[common_index, 'Effect']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create and train the logistic regression model
model = LogisticRegression(random_state=42)
model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test_scaled)

# Evaluate the model
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Print model coefficients
print("\nModel Coefficients:")
for feature, coef in zip(X.columns, model.coef_[0]):
    print(f"{feature}: {coef}")

# Print model intercept
print(f"\nIntercept: {model.intercept_[0]}")

# Calculate and print odds ratios
print("\nOdds Ratios:")
odds_ratios = np.exp(model.coef_[0])
for feature, odds_ratio in zip(X.columns, odds_ratios):
    print(f"{feature}: {odds_ratio}")
# Out:
# Confusion Matrix:
# [[10  2]
#  [ 1  2]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87        12
#            1       0.50      0.67      0.57         3
#
#     accuracy                           0.80        15
#    macro avg       0.70      0.75      0.72        15
# weighted avg       0.83      0.80      0.81        15
#
#
# Model Coefficients:
# Spread: 0.597252573715465
# 0: 0.3183827715732305
#
# Intercept: -0.17757547558236816
#
# Odds Ratios:
# Spread: 1.8171195340073873
# 0: 1.3749024340868643
